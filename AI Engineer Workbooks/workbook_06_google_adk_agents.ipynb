# %% [markdown]
# # Workbook 6: Building AI Agents with Google ADK
#
# ## Prerequisites
# - Completed Workbook 5: Working with LLMs and APIs
# - Familiarity with your `my_agent` project structure
# - Understanding of tools, prompts, and basic RAG
#
# ## Learning Objectives
# - Understand agent architecture in Google ADK
# - Add tools and routing behavior to agents
# - Explore multi-agent system patterns
# - Connect concepts directly to your `my_agent/agent.py` work

# %% [markdown]
# ## Part 1: Understand the Current Agent

# %%
from pathlib import Path
print(Path('my_agent/agent.py').read_text())

# %% [markdown]
# ### Exercise 1.1: Identify Agent Components
# Extract model, name, description, and instruction from `my_agent/agent.py`.

# %%
components = {
    'model': None,
    'name': None,
    'description': None,
    'instruction': None,
}
print(components)

# %% [markdown]
# ### Exercise 1.2: Environment-Driven Config
# Load model name from `.env` with a safe default fallback.

# %%
import os
from dotenv import load_dotenv

load_dotenv('my_agent/.env')
model_name = None  # os.getenv('ADK_MODEL', '...')
print(model_name)

# %% [markdown]
# ## Part 2: Tooling Basics

# %% [markdown]
# ### Exercise 2.1: Simple Tool Function
# Return Python files under `my_agent/`.

# %%
from pathlib import Path

def get_project_files(root='my_agent'):
    # Your code here
    return None

print(get_project_files())

# %% [markdown]
# ### Exercise 2.2: Safe Calculator Tool
# Allow digits, spaces, and + - * / ( ) only.

# %%
import re

def safe_calculator(expr: str):
    # Your code here
    return None

print(safe_calculator('(3 + 5) * 2'))

# %% [markdown]
# ## Part 3: ADK Agent with Tools

# %% [markdown]
# ### Exercise 3.1: Tool-Augmented Agent
# Create an ADK agent and prepare for tool registration (API differs by ADK release).

# %%
from google.adk.agents.llm_agent import Agent

tool_agent = Agent(
    model='<FILL_IN_MODEL>',
    name='tool_agent',
    description='Agent with utility tools',
    instruction='Use tools when they improve reliability',
    # tools=[...]
)
print(tool_agent)

# %% [markdown]
# ### Exercise 3.2: Tool Usage Instructions
# Write system instructions that tell the agent when and how to use tools.

# %%
tool_instruction = ''
print(tool_instruction)

# %% [markdown]
# ## Part 4: Multi-Agent Patterns

# %% [markdown]
# ### Exercise 4.1: Planner-Executor Pattern
# Define a structured plan with ownership for each step.

# %%
from dataclasses import dataclass
from typing import List

@dataclass
class PlanStep:
    step: str
    owner: str

sample_plan: List[PlanStep] = []
print(sample_plan)

# %% [markdown]
# ### Exercise 4.2: Critic Loop
# Review outputs for correctness, completeness, and safety.

# %%
def critic_review(answer: str):
    # Your code here
    return {
        'is_correct': None,
        'is_complete': None,
        'safety_ok': None,
        'feedback': None,
    }

print(critic_review('sample'))

# %% [markdown]
# ## Part 5: Connect to Your `my_agent` Work

# %% [markdown]
# ### Exercise 5.1: Improve `my_agent/agent.py`
# Draft a stronger root agent config before applying changes.

# %%
updated_agent_py = ''
print(updated_agent_py)

# %% [markdown]
# ### Exercise 5.2: Agent Test Checklist
# Create prompts for normal, tool-use, ambiguous, and safety cases.

# %%
test_prompts = [None, None, None, None]
print(test_prompts)

# %% [markdown]
# ## Part 6: Challenge Problems

# %% [markdown]
# ### Challenge 1: Domain Specialist Multi-Agent System
# Design intake, resolver, and policy checker agents.

# %%
# Your code here

# %% [markdown]
# ### Challenge 2: Tool Reliability Fallbacks
# Implement retry and fallback handling for tool failures.

# %%
# Your code here

# %% [markdown]
# ### Challenge 3: Add RAG Memory
# Ground responses using lightweight retrieval from project docs.

# %%
# Your code here

# %% [markdown]
# ## Summary
#
# In this workbook, you practiced:
# - Reading and improving ADK agent configuration
# - Creating and using tool-like functions
# - Designing multi-agent workflows
# - Connecting these patterns to `my_agent/agent.py`
#
# ### Next Steps
# Move on to Workbook 7: Advanced Topics and Deployment.
