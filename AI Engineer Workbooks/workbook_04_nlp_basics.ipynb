# %% [markdown]
# # Workbook 4: Natural Language Processing Basics
#
# ## Prerequisites
# - Completed Workbook 3: Deep Learning with PyTorch and TensorFlow
# - Comfort with Python, NumPy, and Pandas
# - Basic understanding of vectors and matrices
#
# ## Learning Objectives
# - Perform core text preprocessing steps
# - Understand tokenization and vocabulary construction
# - Work with embeddings and similarity
# - Build intuition for attention and transformers

# %% [markdown]
# ## Part 1: Text Preprocessing

# %%
import re
import numpy as np
import pandas as pd

# %% [markdown]
# ### Exercise 1.1: Clean Raw Text
# Lowercase, remove punctuation, remove extra spaces, and split into tokens.

# %%
text = 'AI Engineering!!! is awesome...   Right?'

# Your code here
clean_text = None
tokens = None

print('Clean text:', clean_text)
print('Tokens:', tokens)

# %% [markdown]
# ### Exercise 1.2: Build a Vocabulary
# Create a token-to-id vocabulary. Reserve id 0 for <PAD> and id 1 for <UNK>.

# %%
sentences = ['llms help with coding', 'agents call tools', 'llms use tokenization']
# Your code here
vocab = None
print(vocab)

# %% [markdown]
# ## Part 2: Tokenization and Encoding

# %% [markdown]
# ### Exercise 2.1: Word-Level Tokenization
# Map tokens to ids and use <UNK> for unseen terms.

# %%
def encode(text, vocab):
    # Your code here
    return None

print(encode('llms call unknown tools', vocab))

# %% [markdown]
# ### Exercise 2.2: Padding and Attention Mask
# Pad variable-length sequences and create masks (1 real token, 0 padding).

# %%
sequences = [[5, 9, 2], [7, 1], [4, 3, 8, 6]]
max_len = 6

# Your code here
padded = None
attention_masks = None

print(padded)
print(attention_masks)

# %% [markdown]
# ## Part 3: Embeddings

# %%
import torch
import torch.nn as nn

# %% [markdown]
# ### Exercise 3.1: Learnable Embedding Layer
# Create `nn.Embedding` and look up vectors for sample ids.

# %%
vocab_size = 20 if 'vocab' not in globals() or vocab is None else len(vocab)
embedding_dim = 8
# Your code here
embedding = None
sample_ids = torch.tensor([2, 3, 4, 1])
embedded = None
print(None if embedded is None else embedded.shape)

# %% [markdown]
# ### Exercise 3.2: Cosine Similarity
# Compute cosine similarity for two embedding vectors.

# %%
# Your code here
vec_a = None
vec_b = None
similarity = None
print(similarity)

# %% [markdown]
# ## Part 4: Attention Mechanism Basics

# %% [markdown]
# ### Exercise 4.1: Scaled Dot-Product Attention
# Implement scores, softmax weights, and context output.

# %%
Q = torch.randn(1, 4, 8)
K = torch.randn(1, 4, 8)
V = torch.randn(1, 4, 8)

# Your code here
scores = None
weights = None
context = None

print(None if weights is None else weights.shape)
print(None if context is None else context.shape)

# %% [markdown]
# ### Exercise 4.2: Visualize Attention Weights
# Plot a heatmap for one attention matrix.

# %%
import matplotlib.pyplot as plt
# Your code here

# %% [markdown]
# ## Part 5: Transformers Introduction

# %% [markdown]
# ### Exercise 5.1: Pretrained Tokenizer
# Load `distilbert-base-uncased` tokenizer and inspect ids/masks.

# %%
from transformers import AutoTokenizer
# Your code here
tokenizer = None
batch = None
print(batch)

# %% [markdown]
# ### Exercise 5.2: Pretrained Encoder
# Load encoder and inspect `last_hidden_state` shape.

# %%
from transformers import AutoModel
# Your code here
model = None
outputs = None
print(None if outputs is None else outputs.last_hidden_state.shape)

# %% [markdown]
# ## Part 6: Challenge Problems

# %% [markdown]
# ### Challenge 1: Mini Text Classifier
# Use tokenization, embeddings, pooling, and linear classification.

# %%
# Your code here

# %% [markdown]
# ### Challenge 2: Compare Word-Level and Subword Tokenization
# Compare token splits for domain-specific words.

# %%
# Your code here

# %% [markdown]
# ### Challenge 3: Explain Attention
# Write a 6-10 line explanation plus a toy example.

# %%
explanation = ''

# %% [markdown]
# ## Summary
#
# In this workbook, you practiced:
# - Cleaning and tokenizing text
# - Building vocabularies and encoded sequences
# - Working with embedding vectors
# - Implementing attention basics
# - Using pretrained transformer tokenizers and encoders
#
# ### Next Steps
# Move on to Workbook 5: Working with LLMs and APIs.
