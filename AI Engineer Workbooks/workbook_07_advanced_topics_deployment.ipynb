# %% [markdown]
# # Workbook 7: Advanced Topics and Deployment
#
# ## Prerequisites
# - Completed Workbook 6: Building AI Agents with Google ADK
# - Basic familiarity with Docker, APIs, and cloud deployment
# - Understanding of model evaluation and monitoring metrics
#
# ## Learning Objectives
# - Optimize model performance and inference cost
# - Deploy AI systems with reproducible infrastructure
# - Monitor quality, latency, and reliability in production
# - Apply production readiness and safety best practices

# %% [markdown]
# ## Part 1: Model Optimization

# %%
import time
import numpy as np

# %% [markdown]
# ### Exercise 1.1: Benchmark Baseline Inference
# Measure average latency over N runs.

# %%
def benchmark(fn, runs=20):
    # Your code here
    return None

# %% [markdown]
# ### Exercise 1.2: Optimization Plan
# Document quantization, distillation, caching, and batching tradeoffs.

# %%
import pandas as pd
optimization_plan = pd.DataFrame([
    {'method': 'quantization', 'benefit': None, 'tradeoff': None},
    {'method': 'distillation', 'benefit': None, 'tradeoff': None},
    {'method': 'caching', 'benefit': None, 'tradeoff': None},
    {'method': 'batching', 'benefit': None, 'tradeoff': None},
])
print(optimization_plan)

# %% [markdown]
# ## Part 2: Deployment Architecture

# %% [markdown]
# ### Exercise 2.1: Serving Interface
# Define request and response schemas with pydantic.

# %%
from pydantic import BaseModel
from typing import Optional, List

class PredictRequest(BaseModel):
    input_text: str
    user_id: Optional[str] = None

class PredictResponse(BaseModel):
    output_text: str
    citations: List[str] = []
    latency_ms: float

# %% [markdown]
# ### Exercise 2.2: FastAPI Endpoint
# Create a `/predict` endpoint that returns `PredictResponse`.

# %%
from fastapi import FastAPI

app = FastAPI()

@app.post('/predict', response_model=PredictResponse)
def predict(req: PredictRequest):
    # Your code here
    return PredictResponse(output_text='', citations=[], latency_ms=0.0)

# %% [markdown]
# ## Part 3: Monitoring and Observability

# %% [markdown]
# ### Exercise 3.1: Define Production Metrics
# Track latency, errors, token usage, and quality signals.

# %%
metrics = {
    'requests_total': 0,
    'latency_ms': [],
    'errors_total': 0,
    'token_usage_total': 0,
    'factuality_failures': 0,
}
print(metrics)

# %% [markdown]
# ### Exercise 3.2: Alerting Rules
# Define threshold conditions for latency, error rate, cost, and quality.

# %%
alert_rules = [
    {'name': 'latency_p95_high', 'condition': None, 'severity': 'warning'},
    {'name': 'error_rate_high', 'condition': None, 'severity': 'critical'},
    {'name': 'cost_spike', 'condition': None, 'severity': 'warning'},
    {'name': 'quality_drop', 'condition': None, 'severity': 'critical'},
]
print(alert_rules)

# %% [markdown]
# ## Part 4: Reliability and Safety

# %% [markdown]
# ### Exercise 4.1: Failure Mode Analysis
# List at least 8 failure modes and mitigations.

# %%
failure_modes = [{'failure': None, 'mitigation': None}]
print(failure_modes)

# %% [markdown]
# ### Exercise 4.2: Guardrails Pipeline
# Define pre and post checks for injection, PII, unsafe output, and unsupported claims.

# %%
def pre_check(user_input: str):
    # Your code here
    return {'ok': True, 'reason': None}

def post_check(model_output: str):
    # Your code here
    return {'ok': True, 'reason': None}

# %% [markdown]
# ## Part 5: CI/CD and Release Strategy

# %% [markdown]
# ### Exercise 5.1: Production Checklist
# Create checklist items for testing, evals, load test, rollback, and incidents.

# %%
deployment_checklist = {
    'unit_tests': None,
    'integration_tests': None,
    'evaluation_suite': None,
    'load_test': None,
    'rollback_plan': None,
    'on_call_ready': None,
}
print(deployment_checklist)

# %% [markdown]
# ### Exercise 5.2: Canary Rollout Plan
# Write four rollout steps with success/failure criteria.

# %%
canary_plan = [None, None, None, None]
print(canary_plan)

# %% [markdown]
# ## Part 6: Challenge Problems

# %% [markdown]
# ### Challenge 1: Evaluation Dashboard Spec
# Define sections, charts, and owners.

# %%
# Your code here

# %% [markdown]
# ### Challenge 2: Cost Optimization Simulation
# Estimate spend under three model options given traffic assumptions.

# %%
# Your code here

# %% [markdown]
# ### Challenge 3: Incident Retrospective Template
# Create a reusable postmortem template.

# %%
# Your code here

# %% [markdown]
# ## Summary
#
# In this workbook, you practiced:
# - Optimization strategies for inference and cost
# - Deployment interface and API design
# - Monitoring, alerting, and reliability planning
# - Safety guardrails and incident readiness
# - Production checklists and rollout strategy
#
# ### Next Steps
# Apply these patterns to deploy and operate your `my_agent` project in a real environment.
