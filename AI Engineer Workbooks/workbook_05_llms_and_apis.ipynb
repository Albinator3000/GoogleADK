# %% [markdown]
# # Workbook 5: Working with LLMs and APIs
#
# ## Prerequisites
# - Completed Workbook 4: NLP Basics
# - Comfort with HTTP APIs and Python functions
# - API keys for at least one LLM provider
#
# ## Learning Objectives
# - Make LLM API calls using OpenAI and Anthropic clients
# - Apply prompt engineering patterns for better outputs
# - Build a simple retrieval-augmented generation (RAG) workflow
# - Evaluate response quality and reliability

# %% [markdown]
# ## Part 1: API Setup and Key Management

# %%
import os
from dotenv import load_dotenv

load_dotenv()
print('OpenAI key found:', os.getenv('OPENAI_API_KEY') is not None)
print('Anthropic key found:', os.getenv('ANTHROPIC_API_KEY') is not None)

# %% [markdown]
# ### Exercise 1.1: Validate Environment Configuration
# Check required env vars and report missing ones.

# %%
required_vars = ['OPENAI_API_KEY', 'ANTHROPIC_API_KEY']
missing = []
# Your code here
print('Missing variables:', missing)

# %% [markdown]
# ### Exercise 1.2: Safe API Wrapper
# Create a helper that standardizes provider responses and errors.

# %%
def call_llm(provider, model, prompt, temperature=0.2):
    # Return {'provider':..., 'model':..., 'content':..., 'error':...}
    # Your code here
    return None

# %% [markdown]
# ## Part 2: OpenAI and Anthropic Usage

# %% [markdown]
# ### Exercise 2.1: OpenAI Call
# Create a short prompt and print model output.

# %%
from openai import OpenAI

client = OpenAI(api_key=os.getenv('OPENAI_API_KEY'))
# Your code here
response = None
# print(response.choices[0].message.content)

# %% [markdown]
# ### Exercise 2.2: Anthropic Call
# Call Anthropic with similar prompt and compare outputs.

# %%
import anthropic

client = anthropic.Anthropic(api_key=os.getenv('ANTHROPIC_API_KEY'))
# Your code here
response = None
# print(response.content[0].text)

# %% [markdown]
# ## Part 3: Prompt Engineering

# %% [markdown]
# ### Exercise 3.1: Prompt Patterns
# Create zero-shot, few-shot, reasoning, and JSON-output templates.

# %%
prompt_templates = {
    'zero_shot': None,
    'few_shot': None,
    'reasoning': None,
    'json_output': None,
}
print(prompt_templates)

# %% [markdown]
# ### Exercise 3.2: Prompt Evaluation Harness
# Compare prompt variants by quality, format compliance, and latency.

# %%
import time

task = 'Summarize this meeting note into 3 bullet points.'
results = []
# Your code here
print(results)

# %% [markdown]
# ## Part 4: Structured Output and Tools

# %% [markdown]
# ### Exercise 4.1: Tool Schema
# Define JSON schema for `create_calendar_event`.

# %%
tool_schema = {
    'name': 'create_calendar_event',
    'description': 'Create a calendar event',
    'parameters': None,
}
print(tool_schema)

# %% [markdown]
# ### Exercise 4.2: Output Validation
# Validate model JSON output with pydantic or manual checks.

# %%
from typing import Dict, Any

def validate_event(payload: Dict[str, Any]) -> bool:
    # Your code here
    return False

# %% [markdown]
# ## Part 5: RAG Fundamentals

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### Exercise 5.1: Build a Tiny Retriever
# Vectorize docs, score query similarity, and return top-2 docs.

# %%
docs = [
    'RAG combines retrieval with generation.',
    'Vector databases store embeddings for semantic search.',
    'Prompt engineering improves output consistency.',
    'Monitoring tracks latency and hallucinations in production.',
]
query = 'How do I improve factual accuracy with external knowledge?'
# Your code here
retrieved = None
print(retrieved)

# %% [markdown]
# ### Exercise 5.2: RAG Prompt Construction
# Compose question + retrieved context + citation instructions.

# %%
question = 'Explain RAG in practical terms.'
retrieved_context = ['[doc_1] ...', '[doc_2] ...']
# Your code here
rag_prompt = None
print(rag_prompt)

# %% [markdown]
# ## Part 6: End-to-End Mini RAG

# %% [markdown]
# ### Exercise 6.1: Retrieve -> Augment -> Generate
# Implement an `answer(query)` pipeline.

# %%
def retrieve(query):
    # Your code here
    return None

def augment(query, contexts):
    # Your code here
    return None

def generate(prompt):
    # Your code here
    return None

def answer(query):
    return generate(augment(query, retrieve(query)))

print(answer('What is RAG and why use it?'))

# %% [markdown]
# ## Part 7: Challenge Problems

# %% [markdown]
# ### Challenge 1: Citation Verification
# Reject responses that cite unsupported sources.

# %%
# Your code here

# %% [markdown]
# ### Challenge 2: Prompt A/B Testing
# Evaluate two prompt variants over 20 tasks.

# %%
# Your code here

# %% [markdown]
# ### Challenge 3: Cost and Latency Dashboard
# Track tokens, request time, and estimated cost.

# %%
# Your code here

# %% [markdown]
# ## Summary
#
# In this workbook, you practiced:
# - Managing API credentials safely
# - Calling OpenAI and Anthropic models
# - Designing and evaluating prompt templates
# - Working with structured output schemas
# - Building a minimal RAG pipeline
#
# ### Next Steps
# Move on to Workbook 6: Building AI Agents with Google ADK.
